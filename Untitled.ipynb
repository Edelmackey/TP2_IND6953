# %% [markdown]
# # IND6953N Technologies financières pour ingénieurs - TP2
#
# ## Étudiants:
# 1. Raphaël Lacoste-Cordeau (1835188)
# 2. Sarah Clohé Lacoste ()
# 3. Samuel Charboneau ()
# 4. Rémi Rocheleau (12312313)
# 5. François Sylvestre ()
#
# ## Date de remise : 21 Avril 2020
# ---

# %% [markdown]
# ## 1. En premier comme dans toute analyse statistique, faites l’analyse descriptive de vos données.
# a.  Mesures de base - Moy.,min, max, quantile, nombre etc.

# %%
import datetime
import matplotlib.pyplot as plt
import pandas as pd
import numpy  as np
import math as m

# Pour lire les données de Yahoo Finance, vous devez installer le toolbox yfinance
import yfinance as yf 

start_sp = datetime.datetime(2006,3,31)
end_sp = datetime.datetime(2020, 3,31)

# Use Backstone ETF


BLack_ETF=['IVV','IWF','IJH','IJR','IWM','IWD','ITOT','IVW','IWB','IWR','DVY',
            'IVE','IWP','IWS','IWV','IUSG','IWO','IWN','IBB','IJK','IUSV',
            'OEF','IJS','IJJ','IYW','IHI','IJT','ITA','IGV','IYH','SOXX','EWC',
            'IGM','IYF','JKE','SUSA','IDU','IYY','IYG','JKD','IYC','IYJ','JKG',
            'IWC','IYK','JKF','JKH','IYT','JKI','IYZ','IGE','IYE','JKL','IYM',
            'JKJ','JKK','IGN']

Data = yf.download(BLack_ETF, start=start_sp, end=end_sp,group_by="ticker")

Data.describe()
# To access data for SP500
#SP500_dat=Data['IVW']

# To access the adjusted close price, use
#Data['IVW']['Adj Close']

# Graph data
#Data['IVW']['Adj Close'].plot(grid=True)

# To get Information about a ticker
#df = Data["IVW"]
# Out:
# [*********************100%***********************]  57 of 57 completed
#                JKH                                                      \
#               Open         High          Low        Close    Adj Close
# count  3523.000000  3523.000000  3523.000000  3523.000000  3523.000000
# mean    133.918720   134.540494   133.193721   133.908331   130.851568
# std      55.763470    55.869450    55.627171    55.740896    56.754402
# min      43.380001    45.040001    41.860001    42.520000    40.441044
# 25%      89.910000    90.639999    89.060001    90.005001    85.648521
# 50%     117.209999   117.480003   116.900002   117.199997   113.655540
# 75%     166.120003   166.639999   165.570000   166.210007   163.287056
# max     285.369995   286.609985   284.910004   285.769989   285.619446
#
#                               IYG                                         ...  \
#               Volume         Open         High          Low        Close  ...
# count    3523.000000  3523.000000  3523.000000  3523.000000  3523.000000  ...
# mean    17091.853534    89.306066    89.984706    88.539327    89.275177  ...
# std     35932.455944    32.147394    32.195119    32.100341    32.143615  ...
# min         0.000000    23.309999    24.889999    22.639999    23.520000  ...
# 25%      2700.000000    57.419998    57.740002    56.929998    57.390001  ...
# 50%      6300.000000    86.279999    86.959999    85.660004    86.260002  ...
# 75%     15700.000000   120.895000   121.579998   120.000000   120.980000  ...
# max    883600.000000   155.820007   156.970001   155.500000   156.080002  ...
#
#                JKK                                                   OEF  \
#                Low        Close    Adj Close         Volume         Open
# count  3523.000000  3523.000000  3523.000000    3523.000000  3523.000000
# mean    115.049043   115.723863   112.216359    9830.371842    80.391399
# std      47.275183    47.371833    48.621218   16710.678376    27.102911
# min      36.660000    36.830002    34.597805       0.000000    32.369999
# 25%      74.980003    75.540001    70.593498    1900.000000    58.995001
# 50%     102.690002   103.000000    98.818108    4100.000000    71.739998
# 75%     144.730003   145.080002   141.521812   10650.000000    96.195000
# max     226.309998   226.309998   226.225204  241100.000000   152.080002
#
#
#               High          Low        Close    Adj Close        Volume
# count  3523.000000  3523.000000  3523.000000  3523.000000  3.523000e+03
# mean     80.805416    79.926506    80.394794    71.398057  1.001492e+06
# std      27.171229    27.039292    27.112241    29.970177  9.989297e+05
# min      33.400002    32.020000    32.500000    25.652834  4.400000e+04
# 25%      59.335001    58.730000    59.025000    47.367466  4.141000e+05
# 50%      72.029999    71.459999    71.760002    60.833019  6.740000e+05
# 75%      96.415001    95.855000    96.195000    89.405949  1.180850e+06
# max     152.580002   151.750000   152.279999   151.475754  1.170000e+07
#
# [8 rows x 342 columns]

# %% [markdown]
# b.	L’analyse peut être présentée sous forme de tableaux et graphiques

# %%
Data2 = Data.iloc[:, Data.columns.get_level_values(1)=='Adj Close']
Data2.describe()
# Out:
#                JKH          IYG          IJR          JKE          IJS  \
#          Adj Close    Adj Close    Adj Close    Adj Close    Adj Close
# count  3523.000000  3523.000000  3523.000000  3523.000000  3523.000000
# mean    130.851568    80.806975    44.742278    95.720902    89.721209
# std      56.754402    31.049687    19.948247    47.069668    37.219823
# min      40.441044    20.204138    12.972113    31.788940    26.903204
# 25%      85.648521    50.628695    27.480909    57.954540    57.700457
# 50%     113.655540    78.533897    39.023281    76.376312    79.864578
# 75%     163.287056   104.341133    57.904652   118.838100   115.658028
# max     285.619446   154.892761    87.845085   235.197891   167.907471
#
#                IWN          IJT          IYZ          IJK          IVW  ...  \
#          Adj Close    Adj Close    Adj Close    Adj Close    Adj Close  ...
# count  3523.000000  3523.000000  3523.000000  3523.000000  3523.000000  ...
# mean     77.871293   100.392031    22.344859   128.443661    90.274837  ...
# std      27.264793    47.136550     5.524415    55.894178    43.875731  ...
# min      25.316549    28.370533     9.440839    38.731476    30.554737  ...
# 25%      55.302929    58.895233    17.596956    77.496742    53.801075  ...
# 50%      72.191277    86.716614    23.043299   117.060699    73.779655  ...
# 75%      95.894093   130.632393    26.957894   168.354408   115.003387  ...
# max     132.383820   205.510742    33.502102   246.955765   209.909103  ...
#
#                IYT         SUSA          EWC          JKF          IYE  \
#          Adj Close    Adj Close    Adj Close    Adj Close    Adj Close
# count  3523.000000  3523.000000  3523.000000  3523.000000  3523.000000
# mean    113.296775    68.505054    23.592442    65.555745    31.431177
# std      45.334831    27.371289     3.586534    21.971761     5.772306
# min      33.506668    24.677376    10.993851    25.684568    12.356944
# 25%      74.161049    46.851570    21.674120    48.362068    27.670032
# 50%     100.530045    59.315865    24.112261    60.744301    32.072411
# 75%     151.381393    85.354195    26.132184    79.873394    35.061829
# max     203.311630   141.109848    30.780001   116.566925    47.061329
#
#                IWV          IWB          JKJ          JKK          OEF
#          Adj Close    Adj Close    Adj Close    Adj Close    Adj Close
# count  3523.000000  3523.000000  3523.000000  3523.000000  3523.000000
# mean     95.002425    88.910114   105.911599   112.216359    71.398057
# std      40.356569    38.225800    41.372001    48.621218    29.970177
# min      31.834858    29.834320    31.367994    34.597805    25.652834
# 25%      62.117748    57.841467    70.430481    70.593498    47.367466
# 50%      81.674683    75.988075    96.677216    98.818108    60.833019
# 75%     119.951778   112.516506   136.151527   141.521812    89.405949
# max     197.116180   187.020889   191.034607   226.225204   151.475754
#
# [8 rows x 57 columns]

# %% [markdown]
# ## 2.	Par la suite, séparez votre échantillon en deux portions
# a.	Échantillon d’entraînement (70% du total)

# %%
Data_train =

# %% [markdown]
# b.	Échantillon de test (30% du total)
